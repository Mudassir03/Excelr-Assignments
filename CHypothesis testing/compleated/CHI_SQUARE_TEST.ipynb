# %% [markdown]
# ## Hypothesis statment
# Null hypothesis(H0): There is no association between the type of device purchased and the customer's satisfaction level.
#
# Alternate hypothesis(H1): There is an association between the type of device purchased and the customer's satisfaction level.
#
#
#
#
# *   If Chi-square test value falls under critical region H0 is rejected and h1 is accepted.
# *    If Chi-square test value falls under Accepted region H0 is accepted and h1 is rejected.

# %% [markdown]
# ### Calculating chi-square test value

# %%
from scipy.stats import chi2_contingency
import numpy as np

data = np.array([[50, 70],
                     [80, 100],
                     [60, 90],
                     [30, 50],
                     [20, 50]])






chi2, p, dof, expected = chi2_contingency(data)

expected=pd.DataFrame(expected)
expected.columns=['Smart Thermostat','Smart Light']
expected.index=['Very Satisfied', 'Satisfied', 'Neutral', 'Unsatisfied', 'Very Unsatisfied']

print("Chi-square test:", chi2.round(3))
print("P-value:", p.round(3))
print("Degrees of freedom:", dof)
print("Expected frequencies table:")
print(expected)
# Out:
# Chi-square test: 5.638
# P-value: 0.228
# Degrees of freedom: 4
# Expected frequencies table:
#                   Smart Thermostat  Smart Light
# Very Satisfied                48.0         72.0
# Satisfied                     72.0        108.0
# Neutral                       60.0         90.0
# Unsatisfied                   32.0         48.0
# Very Unsatisfied              28.0         42.0

# %% [markdown]
# ### Determine the Critical Value

# %%
import scipy.stats as stats
chi_table=stats.chi2.ppf(q=0.95, df=4)
print('chi-table value',chi_table.round(3))
# Out:
# chi-table value 9.488

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Conclusion

# %% [markdown]
# Chi-square test value falls under Accepted region H0 is accepted and h1 is rejected.
#
# **There is no association between the type of device purchased and the customer's satisfaction level**
